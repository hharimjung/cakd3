# %% [raw]
# 0 : 자동 추천 or 달별 꽃 추천 (or 직접 선택)
# 1-(1) : 현재 날짜를 추출하여 해당 시기의 제철 꽃을 자동으로 추천
# 1-(2) : 원하는 달을 직접 선택하게 하고, 그 달에 해당하는 꽃 리스트를 추출
# (ex. 1월 : a,b,c,,,, 2월 : e,f,g,,,, 3월 : h,i,j,,,, )
# 2 : 해당 꽃에 대한 꽃말 출력
# 3 : 다른 꽃의 꽃말도 궁금하냐는 질문에 대한 선택지 제공
# (ex. “다른 꽃의 꽃말도 궁금하신가요?” y : 선택 창으로 되돌아가서 반복 / n : 종료)
# +) 4: 완전히 종료 전, 사람들이 제일 많이 찾는 꽃 리스트 정보 제공 후 완전 종료

# %%
# flower.py

import datetime

class Flower:
    def __init__(self, flowers): # flower 변수 설정.
        self.flowers = flowers
        
    def one(self): # 1-(1)자동 추천 <완료>
        now = datetime.datetime.now()
        a = now.month
        print('%d월의 추천 꽃은 [%s]이며, 꽃말은 [%s]입니다.' %(a,flowers[a][0][0],flowers[a][0][1])) 
        # flowers[월],[꽃],[꽃말]
        
    def two(self,month_Chioce): # 1-(2) 달별꽃
        two_list = []
        for i in range(0,3):
            two_list.append(flowers[month_Chioce][i][0])
        print('%d월을 선택하셨습니다. %d월의 추천 꽃은 %s입니다.' %(month_Chioce,month_Chioce,two_list))
        print("-"*50)
        print(input('꽃말이 궁금하시다면 꽃 이름을 입력해주세요> '))
    
    def three(self): # 1-(3) 직접선택
        print("미완성")

def menu():
    choice = int(input('원하시는 항목을 선택해주세요(자동추천:1, 달별꽃:2, 직접선택:3)> \n'))
    print("-"*50)
    return choice
        
def flower_List():
    flower = [
    [], # 인덱스 0번값을 비워둠. 1 = 1월부터 시작하게끔 설정.
    [
        # 1월
        ["수선화","매력과 특별함"], ["스노우드롭", "희망"], ["샤프란","후회없는 청춘"]
    ],
    [
        # 2월
        ["제비꽃", "지혜와 희망"], ["월계수","명예"],["은매화","사랑의 속삭임"]
    ], 
    [
        # 3월
        ["수선화","가정의 행복,존경,우정"], ["데이지","명랑"], ["박하","미덕"]
    ],
    [
        # 4월        
        ["스위트 피","사랑,젊음,순결"],["아네모네","기대"],["나팔꽃","기쁨"]
    ],
    [
        # 5월
        ["은방울꽃","사랑,열정,아름다움,완벽함"],["민들레","신탁"],["수련","청순한 마음"]
    ],
    [
        # 6월
        ["장미","사랑"],["쟈스민","사랑스러움"],["백리향","용기"]
    ],
    [
        # 7월
        ["라벤더","정절,기대"],["해바라기","애모"],["초롱꽃","감사"]
    ],
    [
        # 8월
        ["글라디올러스","의지의 힘,명예,기억"],["진달래","사랑의 기쁨"],["금잔화","이별의 슬픔"]
    ],
    [
        # 9월
        ["물망초","인내,정신적인 사랑,애정"],["엉겅퀴","엄격"],["로즈마리","기억,추억,헌신"]
    ],
    [
        # 10월
        ["금잔화","맹렬함,우아함,헌신"],["국화","사랑"],["매화","고결한 마음"]
    ],
    [
        # 11월
        ["국화","연민,우정,기쁨"],["메리골드","이별의 슬픔"],["크리스마스로즈","추억"]
    ],
    [
        # 12월
        ["포인세티아","용기,성공,특별한 존재"],["라벤더","기대"],["쑥국화","평화"]
    ]
    ]
    
    return flower

# 인삿말
print('{0:^40}'.format(chr(0x1F338)))
print()
print('안녕하세요. 향기를 선물하는 꽃 자판기입니다.')
print()
print('{0:^40}'.format(chr(0x1F338)))
print()
print("-"*50)

# 첫번째 선택지 선택시 멘트
menu_Choice = menu()    
flowers = flower_List()    
obj = Flower(flowers)
if menu_Choice == 1:
    print('자동추천을 선택하셨습니다. 계절을 담은 제철꽃을 추천드릴게요.')
    obj.one()
elif menu_Choice == 2:
    month_Chioce = int(input('달별꽃을 선택하셨습니다. 원하는 달을 입력해주세요.> '))
    obj.two(month_Chioce)
else:
    print('직접선택을 선택하셨습니다. 알아보고싶은 꽃을 입력해주세요.\n')
    obj.three()
# Out:
#                    🌸
#
# 안녕하세요. 향기를 선물하는 꽃 자판기입니다.
#
#                    🌸
#
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-135-b5de849ba0a0> in <module>
#      94
#      95 # 첫번째 선택지 선택시 멘트
# ---> 96 menu_Choice = menu()
#      97 flowers = flower_List()
#      98 obj = Flower(flowers)
#
# <ipython-input-135-b5de849ba0a0> in menu()
#      25
#      26 def menu():
# ---> 27     choice = int(input('원하시는 항목을 선택해주세요(자동추천:1, 달별꽃:2, 직접선택:3)> \n'))
#      28     print("-"*50)
#      29     return choice
#
# C:\anaconda3\envs\cakd3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
# ...

# %%
# flower.py

import datetime

class Flower:
    def __init__(self, flowers): # flower 변수 설정.
        self.flowers = flowers
        
    def one(self): # 1-(1)자동 추천 <완료>
        now = datetime.datetime.now()
        a = now.month
        print('%d월의 추천 꽃은 [%s]이며, 꽃말은 [%s]입니다.' %(a,flowers[a][0][0],flowers[a][0][1])) 
        # flowers[월],[꽃],[꽃말]
        
    def two(self,month_Chioce): # 1-(2) 달별꽃
        two_list = []
        for i in range(0,3):
            two_list.append(flowers[month_Chioce][i][0])
        print('%d월을 선택하셨습니다. %d월의 추천 꽃은 %s입니다.' %(month_Chioce,month_Chioce,two_list))
        print("-"*50)
        flower_name = input('꽃말이 궁금하시다면 꽃 이름을 입력해주세요> ')
        flower_name_index = two_list.index(flower_name) #index 함수로 필요한 꽃 리스트들 불러오기.
        print('%s의 꽃말은 %s입니다.' %(flower_name, flowers[month_Chioce][flower_name_index][1]))
            
    
    def three(self): # 1-(3) 직접선택
        print("3번")

def menu():
    choice = int(input('원하시는 항목을 선택해주세요(자동추천:1, 달별꽃:2, 직접선택:3)> \n'))
    print("-"*50)
    return choice
        
def flower_List():
    flower = [
    [], # 인덱스 0번값을 비워둠. 1 = 1월부터 시작하게끔 설정.
    [
        # 1월
        ["수선화","매력과 특별함"], ["스노우드롭", "희망"], ["샤프란","후회없는 청춘"]
    ],
    [
        # 2월
        ["제비꽃", "지혜와 희망"], ["월계수","명예"],["은매화","사랑의 속삭임"]
    ], 
    [
        # 3월
        ["수선화","가정의 행복,존경,우정"], ["데이지","명랑"], ["박하","미덕"]
    ],
    [
        # 4월        
        ["스위트 피","사랑,젊음,순결"],["아네모네","기대"],["나팔꽃","기쁨"]
    ],
    [
        # 5월
        ["은방울꽃","사랑,열정,아름다움,완벽함"],["민들레","신탁"],["수련","청순한 마음"]
    ],
    [
        # 6월
        ["장미","사랑"],["쟈스민","사랑스러움"],["백리향","용기"]
    ],
    [
        # 7월
        ["라벤더","정절,기대"],["해바라기","애모"],["초롱꽃","감사"]
    ],
    [
        # 8월
        ["글라디올러스","의지의 힘,명예,기억"],["진달래","사랑의 기쁨"],["금잔화","이별의 슬픔"]
    ],
    [
        # 9월
        ["물망초","인내,정신적인 사랑,애정"],["엉겅퀴","엄격"],["로즈마리","기억,추억,헌신"]
    ],
    [
        # 10월
        ["금잔화","맹렬함,우아함,헌신"],["국화","사랑"],["매화","고결한 마음"]
    ],
    [
        # 11월
        ["국화","연민,우정,기쁨"],["메리골드","이별의 슬픔"],["크리스마스로즈","추억"]
    ],
    [
        # 12월
        ["포인세티아","용기,성공,특별한 존재"],["라벤더","기대"],["쑥국화","평화"]
    ]
    ]
    
    return flower

print('{0:^40}'.format(chr(0x1F338)))
print()
print('안녕하세요. 향기를 선물하는 꽃 자판기입니다.')
print()
print('{0:^40}'.format(chr(0x1F338)))
print()
print("-"*50)
menu_Choice = menu()    
flowers = flower_List()    
obj = Flower(flowers)
if menu_Choice == 1:
    print('자동추천을 선택하셨습니다. 계절을 담은 제철꽃을 추천드릴게요.')
    obj.one()
elif menu_Choice == 2:
    month_Chioce = int(input('달별꽃을 선택하셨습니다. 원하는 달을 입력해주세요.> '))
    obj.two(month_Chioce)
else:
    print('직접선택을 선택하셨습니다. 알아보고싶은 꽃을 입력해주세요.\n')
    obj.three()
# Out:
#                    🌸
#
# 안녕하세요. 향기를 선물하는 꽃 자판기입니다.
#
#                    🌸
#
# --------------------------------------------------
# 원하시는 항목을 선택해주세요(자동추천:1, 달별꽃:2, 직접선택:3)>
# 2
# --------------------------------------------------
# 달별꽃을 선택하셨습니다. 원하는 달을 입력해주세요.> 2
# 2월을 선택하셨습니다. 2월의 추천 꽃은 ['제비꽃', '월계수', '은매화']입니다.
# --------------------------------------------------
# 꽃말이 궁금하시다면 꽃 이름을 입력해주세요> 제비꽃
# 제비꽃의 꽃말은 지혜와 희망입니다.
